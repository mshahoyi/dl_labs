# %% [markdown]
# ![image.png](attachment:4345aaa5-35cd-40ab-aa80-c55d65c06b1c.png)

# %% [markdown]
# ![image.png](attachment:769bc58d-2cda-4f59-aba0-67a991ff7694.png)

# %% [markdown]
# # VGG-16 Optimal Epochs: 38
# # VGG-19 Optimal Epochs: 40
#
# Since validation accuracy is highest at the 40th epoch for both models

# %% [markdown]
# ![image.png](attachment:fb18d89e-1cdc-4ea5-9fc8-7bcf6f2b04f2.png)

# %% [markdown]
# ![image.png](attachment:d4bce563-d90a-4b9c-9f04-221196d60019.png)
