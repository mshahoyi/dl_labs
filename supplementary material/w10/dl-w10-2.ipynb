# %%
from tensorflow import keras
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist
import numpy as np

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.17.1

# %%
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train[0].max()
# Out:
# 255

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

n = 10  # how many records we will display
plt.figure(figsize=(2, 2))

for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ![image.png](attachment:7b66c461-7e86-42f8-8fa2-1cb11eaaaaa2.png)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, UpSampling2D, Reshape, Input

# %%
encode_model = Sequential()

############
# Encoding #
############
encode_model.add(Input((28, 28, 1)))

## FIRST SET OF LAYERS
# CONVOLUTIONAL LAYER
encode_model.add(Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same'))
# POOLING LAYER
encode_model.add(MaxPool2D(pool_size=(2, 2),  padding='same'))

## SECOND SET OF LAYERS
# CONVOLUTIONAL LAYER
encode_model.add(Conv2D(filters=8, kernel_size=(3,3), activation = 'relu', padding='same'))
# POOLING LAYER
encode_model.add(MaxPool2D(pool_size=(2, 2), padding='same'))

encode_model.add(Flatten())
encode_model.add(Dense(7*7*8, activation="relu"))
encode_model.add(Dense(30, activation="relu"))

# %%
############
# Decoding #
############
decode_model = Sequential()

decode_model.add(Dense(7*7*8,activation="relu"))
decode_model.add(Reshape([7,7,8]))

# DeConv1
decode_model.add(Conv2D(filters=8, kernel_size=(3,3), activation='relu', padding='same'))
# Upsampling LAYER
decode_model.add(UpSampling2D((2, 2)))

# Deconv2
decode_model.add(Conv2D(filters=16, kernel_size=(3,3), activation='relu', padding='same'))
# POOLING LAYER
decode_model.add(UpSampling2D((2, 2)))

decode_model.add(Conv2D(1, kernel_size=(3,3), activation='sigmoid', padding='same'))

# %%
autoencoder = Sequential([encode_model, decode_model])

# %%
autoencoder.compile(optimizer='adamw', loss='binary_crossentropy', metrics=['accuracy'])

# %%
autoencoder.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (None, 30)                  │         167,166 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_1 (Sequential)            │ (None, 28, 28, 1)           │          14,049 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 181,215 (707.87 KB)
#  Trainable params: 181,215 (707.87 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras import models

# %%
autoencoder.save('Conv_autoencoder.keras')

# %%
encode_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 28, 28, 16)          │             160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 14, 14, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 14, 14, 8)           │           1,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 7, 7, 8)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 392)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 392)                 │         154,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 30)                  │          11,790 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 167,166 (652.99 KB)
#  Trainable params: 167,166 (652.99 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
decode_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 392)                 │          12,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 7, 7, 8)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 7, 7, 8)             │             584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d (UpSampling2D)         │ (None, 14, 14, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 14, 14, 16)          │           1,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_1 (UpSampling2D)       │ (None, 28, 28, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 28, 28, 1)           │             145 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,049 (54.88 KB)
#  Trainable params: 14,049 (54.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
x_train = x_train.reshape(60000,28,28,1)
x_train = x_train/255
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_test = x_test.reshape(10000, 28, 28, 1)
x_test = x_test/255
x_test.shape
# Out:
# (10000, 28, 28, 1)

# %%
# SID 2371546
history = autoencoder.fit(x=x_train, y=x_train, epochs=46, batch_size=256, shuffle=True, verbose=1, validation_data=(x_test, x_test))
# Out:
# Epoch 1/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.8035 - loss: 0.3441 - val_accuracy: 0.8013 - val_loss: 0.1594
# Epoch 2/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8035 - loss: 0.1482 - val_accuracy: 0.8078 - val_loss: 0.1243
# Epoch 3/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8084 - loss: 0.1232 - val_accuracy: 0.8090 - val_loss: 0.1139
# Epoch 4/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8097 - loss: 0.1144 - val_accuracy: 0.8103 - val_loss: 0.1078
# Epoch 5/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8109 - loss: 0.1089 - val_accuracy: 0.8113 - val_loss: 0.1044
# Epoch 6/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8115 - loss: 0.1046 - val_accuracy: 0.8109 - val_loss: 0.1008
# Epoch 7/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8119 - loss: 0.1015 - val_accuracy: 0.8120 - val_loss: 0.0988
# Epoch 8/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8122 - loss: 0.0992 - val_accuracy: 0.8116 - val_loss: 0.0962
# Epoch 9/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8129 - loss: 0.0971 - val_accuracy: 0.8121 - val_loss: 0.0944
# Epoch 10/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8128 - loss: 0.0956 - val_accuracy: 0.8123 - val_loss: 0.0936
# Epoch 11/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8129 - loss: 0.0946 - val_accuracy: 0.8125 - val_loss: 0.0925
# Epoch 12/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8132 - loss: 0.0934 - val_accuracy: 0.8126 - val_loss: 0.0911
# Epoch 13/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8134 - loss: 0.0927 - val_accuracy: 0.8123 - val_loss: 0.0911
# Epoch 14/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8139 - loss: 0.0916 - val_accuracy: 0.8126 - val_loss: 0.0902
# Epoch 15/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8136 - loss: 0.0912 - val_accuracy: 0.8127 - val_loss: 0.0893
# Epoch 16/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8132 - loss: 0.0909 - val_accuracy: 0.8127 - val_loss: 0.0890
# Epoch 17/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8134 - loss: 0.0903 - val_accuracy: 0.8127 - val_loss: 0.0885
# Epoch 18/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8137 - loss: 0.0895 - val_accuracy: 0.8125 - val_loss: 0.0883
# Epoch 19/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8142 - loss: 0.0888 - val_accuracy: 0.8130 - val_loss: 0.0885
# Epoch 20/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8140 - loss: 0.0889 - val_accuracy: 0.8129 - val_loss: 0.0872
# Epoch 21/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8141 - loss: 0.0884 - val_accuracy: 0.8130 - val_loss: 0.0871
# Epoch 22/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8137 - loss: 0.0881 - val_accuracy: 0.8131 - val_loss: 0.0868
# Epoch 23/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8137 - loss: 0.0879 - val_accuracy: 0.8127 - val_loss: 0.0874
# Epoch 24/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8139 - loss: 0.0874 - val_accuracy: 0.8131 - val_loss: 0.0861
# Epoch 25/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8140 - loss: 0.0874 - val_accuracy: 0.8130 - val_loss: 0.0858
# Epoch 26/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8139 - loss: 0.0870 - val_accuracy: 0.8131 - val_loss: 0.0857
# Epoch 27/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8141 - loss: 0.0867 - val_accuracy: 0.8132 - val_loss: 0.0856
# Epoch 28/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8145 - loss: 0.0863 - val_accuracy: 0.8131 - val_loss: 0.0852
# Epoch 29/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8143 - loss: 0.0862 - val_accuracy: 0.8132 - val_loss: 0.0850
# Epoch 30/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8143 - loss: 0.0860 - val_accuracy: 0.8133 - val_loss: 0.0849
# Epoch 31/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8140 - loss: 0.0858 - val_accuracy: 0.8133 - val_loss: 0.0845
# Epoch 32/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8146 - loss: 0.0854 - val_accuracy: 0.8134 - val_loss: 0.0847
# Epoch 33/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8139 - loss: 0.0855 - val_accuracy: 0.8132 - val_loss: 0.0842
# Epoch 34/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8144 - loss: 0.0851 - val_accuracy: 0.8134 - val_loss: 0.0846
# Epoch 35/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8146 - loss: 0.0851 - val_accuracy: 0.8132 - val_loss: 0.0842
# Epoch 36/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8139 - loss: 0.0850 - val_accuracy: 0.8132 - val_loss: 0.0841
# Epoch 37/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8140 - loss: 0.0847 - val_accuracy: 0.8133 - val_loss: 0.0839
# Epoch 38/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8136 - loss: 0.0848 - val_accuracy: 0.8133 - val_loss: 0.0837
# Epoch 39/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8143 - loss: 0.0845 - val_accuracy: 0.8131 - val_loss: 0.0848
# Epoch 40/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8142 - loss: 0.0845 - val_accuracy: 0.8132 - val_loss: 0.0835
# Epoch 41/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8141 - loss: 0.0842 - val_accuracy: 0.8133 - val_loss: 0.0833
# Epoch 42/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8138 - loss: 0.0843 - val_accuracy: 0.8133 - val_loss: 0.0832
# Epoch 43/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8142 - loss: 0.0840 - val_accuracy: 0.8134 - val_loss: 0.0831
# Epoch 44/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8145 - loss: 0.0839 - val_accuracy: 0.8135 - val_loss: 0.0828
# Epoch 45/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8142 - loss: 0.0838 - val_accuracy: 0.8135 - val_loss: 0.0830
# Epoch 46/46
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8145 - loss: 0.0837 - val_accuracy: 0.8132 - val_loss: 0.0830

# %%
losses = history.history['loss']
losses_val = history.history['val_loss']
epochs = range(1, len(losses) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, losses, 'bo', label='Training loss')
plt.plot(epochs, losses_val, 'b', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss function - binary_crossentropy')
plt.legend()
plt.show()

# %%
accuracy_array = history.history['accuracy']
val_accuracy_array = history.history['val_accuracy']
epochs = range(1, len(accuracy_array) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, accuracy_array, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy_array, 'b', label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10

fig = plt.figure(figsize=(20, 4))
fig.patch.set_facecolor('black')

for i in range(n):
    # display original
    
    ax = plt.subplot(2, n, i + 1)

    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    
    # display reconstruction
    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ![image.png](attachment:f51e6fad-c8b0-48ee-b841-08b51142fe9c.png)

# %%
# optimizer is not so good,
# epoch number should be edded

# %% [markdown]
# ## Lab Logbook requirement:
#
# 1) Copy the autoencoder model and train it with epochs=Z+40,
# where your SID is: XXXXXXZ
# Leave other parameters the same as in Task 2.
#
# 2) Please only add to your Lab Logbook print-screens of:
# - Table of your model autoencoder.summary()
# - Code of your autoencoder.fit()
# - Accuracy detailed graph
# - Document the plot of the decoded images for task 2. Change the colour, appearance, and shape of the plot according to your own choice (see plt.figure() parameters).
#
#
# NOTE: DON'T FORGET TO SAVE AND BACK UP YOUR COMPLETED JUPYTER NOTEBOOK AND LAB LOGBOOK ON GITHUB OR ONEDRIVE.

# %%
# autoencoder_2 = models.load_model('Conv_autoencoder.keras')

# %%
# history_2 =

# %%
#
#
#
