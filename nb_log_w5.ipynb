# %% [markdown]
# ![Screenshot 2025-02-20 at 14.45.19.png](attachment:26f1a4f1-5838-4f46-8501-58fae431b536.png)

# %% [markdown]
# ![Screenshot 2025-02-20 at 14.50.26.png](attachment:b9787ada-9653-4a94-bac4-4c7c0fd3c51e.png)

# %% [markdown]
# ![Screenshot 2025-02-20 at 14.50.17.png](attachment:2853d987-6394-445d-a3e7-95981b17a886.png)

# %% [markdown]
# # Optimal epochs: 14
#
# Based on the above graphs, the optimal number of epochs for my model is 14 epochs because val_loss is at the minimum after that epoch.

# %% [markdown]
# ![Screenshot 2025-02-20 at 14.59.59.png](attachment:6b93b479-ab1e-4d1a-9b99-f21790ca97df.png)
