# %% [markdown]
# # Task 1

# %% [markdown]
# Accuracy: 0.8921

# %% [markdown]
# ![Screenshot 2025-01-30 at 15.56.32.png](attachment:0b2822b8-0d92-4504-a147-98c93ef87e34.png)

# %% [markdown]
# # Task 2

# %% [markdown]
# - Output 1: 0.81898336
# - Output 2: 0.81898336
